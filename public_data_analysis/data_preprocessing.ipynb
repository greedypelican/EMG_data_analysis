# %%
# tasks to do :
# 1. find the best classifier for the similar pattern but different range of values
#    (StandardScaler-standardization, MinMaxScaler-normalization,
#     PCA-dimensional reduction, t-SNE-dimensional reduction)
# 2. classify the data with varying time ranges 
#    ('Down-Scaling', 'Up-Scaling')
# 3. repeat classifying with different window sizes to get the best

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
from scipy import ndimage

col_names=['ch1','ch2','ch3','ch4']
gesture_names = ['Rest','Extension','Flexion','UlnarDeviation','RadialDeviation','Grip','AbductionOfFingers','AdductionOfFingers','Supination','Pronation']

# %% [markdown]
# Reshape the data1~data40 to 3-D arrays having gesture names

# %%
import warnings
warnings.filterwarnings('ignore') # too many warnings (use DataFrame.transpose instead of DataFrame.swapaxes)
c=0
for i in range(40): # data1 to data40
    globals()['data{}'.format(i+1)] = pd.read_csv('/Users/jhr/workspace/GitHub/EMG_data_analysis/Dataset for multi-channel surface electromyography (sEMG) signals of hand gestures/sEMG-dataset/raw/csv/{}_raw.csv'.format(i+1), names=col_names)

    globals()['data{}_patterns'.format(i+1)] = [globals()['data{}'.format(i+1)][r:r + 268000] for r in range(0, len(globals()['data{}'.format(i+1)]), 268000)] #divide the data by 268000 steps at a time

    for j in range(5): # pattern1 to pattern5
        globals()['data{}_gestures{}'.format(i+1,j+1)] = np.array_split(globals()['data{}_patterns'.format(i+1)][j].iloc[4000:204000], 10) #split the data into 10 gestures
        
        for g in range(10): # gesture1 to gesture10
            if i==0: # make a array, the first face of 3-D gesture array
                globals()['{}_signal'.format(gesture_names[g])] = globals()['data{}_gestures{}'.format(i+1,j+1)][g].reset_index(drop=True).to_numpy()[np.newaxis,:] # 3-D arrays after numpy.newaxis having gesture names 
                
            else: # vertically stack the 2-D arrays to the previously generated 3-D array
                globals()['{}_signal'.format(gesture_names[g])] = np.vstack([globals()['{}_signal'.format(gesture_names[g])],globals()['data{}_gestures{}'.format(i+1,j+1)][g].reset_index(drop=True).to_numpy()[np.newaxis,:]])

        c+=1
        #print('i:{} j:{} c:{}'.format(i+1,j+1,c))

# %%
# check the shape of the 3-D arrays
Extension_signal.shape # but why (196, 20000, 4) ?
# Out:
# (196, 20000, 4)

# %% [markdown]
# Standardization and Normalization

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

standardscaler = StandardScaler() # sets values have mean to 0 with standard deviation
minmaxscaler = MinMaxScaler() # sets minimum signal to 0, maximum signal to 1, and other values between them

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

ax.plot(Rest_signal[40][:,0].reshape(-1,1),label='Original',alpha=0.3)
ax.plot(standardscaler.fit_transform(Rest_signal[40][:,0].reshape(-1,1)),label='StandardScaler',alpha=0.6)

plt.legend()
plt.show()

# %% [markdown]
# Apply StandardScaler to all data

# %%
for g in gesture_names:
    for i in range(196):
        if i == 0:
            globals()['{}_signal_standard'.format(g)] = np.ndarray(globals()['{}_signal'.format(g)].shape)
            globals()['{}_signal_standard'.format(g)][i] = standardscaler.fit_transform(globals()['{}_signal'.format(g)][i])
        else:
            globals()['{}_signal_standard'.format(g)][i] = standardscaler.fit_transform(globals()['{}_signal'.format(g)][i])

# %% [markdown]
# Filtering

# %% [markdown]
# 1. Define some filters to go through

# %%
def maximum(raw, box_size, mode='nearest'): # Maximum filter
    raw_maximum=ndimage.maximum_filter(raw,box_size,mode=mode)
    return raw_maximum.real

def denoise_fft(data, ifftn): # Fast Fourier Transformation denoiser
    # apply the FFT
    fft_signal = np.fft.fft(data)
    
    # reconstruct the original signal by apply the IFFT
    fft_signal[ifftn:len(fft_signal)//2]=0
    fft_signal[len(fft_signal)//2:-ifftn]=0
    reconstructed_signal = np.fft.ifft(fft_signal)
    
    return reconstructed_signal.real

def smooth(x,beta): # Kaiser Window Smoothing technique
    window_len=11  # extend the data at beginning and at the end to apply the window at the borders

    s = np.r_[x[window_len-1:0:-1],x,x[-1:-window_len:-1]]
    w = np.kaiser(window_len,beta)
    y = np.convolve(w/w.sum(),s,mode='valid')
    return y[5:len(y)-5]

# %% [markdown]
# 2. Apply Filters

# %%
for i in range(196): # 196(?) samples
    for g in gesture_names: # 10 gestures
        for ch in range(4):
            if i == 0:
                globals()['{}_signal_filtered'.format(g)] = np.ndarray(globals()['{}_signal_standard'.format(g)][:,2000:18000].shape) # make a array shape with a little rest time
                globals()['{}_signal_filtered'.format(g)][i][:,ch] = smooth(denoise_fft(maximum(globals()['{}_signal_standard'.format(g)][i][:,ch],10),10),25)[2000:18000] # apply the filters and cut the rest time
                
            else:
                globals()['{}_signal_filtered'.format(g)][i][:,ch] = smooth(denoise_fft(maximum(globals()['{}_signal_standard'.format(g)][i][:,ch],10),10),25)[2000:18000] # apply the filters and cut the rest time

# %% [markdown]
# 3. Draw the filtered signals to overview

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.plot(Rest_signal_filtered[40],label=['40th '+s for s in col_names],alpha=0.2)
ax.plot(Rest_signal_filtered[80],label=['80th '+s for s in col_names])

plt.legend()
plt.show()

# %% [markdown]
# Dimensionality Reduction

# %% [markdown]
# 1. -1 PCA(Principal Component Analysis) - find a new axis that has a maximum variance between it and the orthogonal vetors from the values (linear)

# %% [markdown]
#  PCA(Principal Component Analysis) - find a new axis that has a maximum variance between it and the orthogonal vetors from the values (linear)

# %%
from sklearn.decomposition import PCA

pca1 = PCA(n_components=1)
pca2 = PCA(n_components=2)
pca3 = PCA(n_components=3)

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_pca'.format(g)] = pca3.fit_transform(globals()['{}_signal_filtered'.format(g)][40])
    globals()['{}_pca'.format(g)] = pca2.fit_transform(globals()['{}_pca'.format(g)])
    globals()['{}_pca'.format(g)] = pca1.fit_transform(globals()['{}_pca'.format(g)])
    ax.plot(globals()['{}_pca'.format(g)],label='{}_PCA'.format(g))

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_pca'.format(g)] = pca3.fit_transform(globals()['{}_signal_filtered'.format(g)][80])
    globals()['{}_pca'.format(g)] = pca2.fit_transform(globals()['{}_pca'.format(g)])
    globals()['{}_pca'.format(g)] = pca1.fit_transform(globals()['{}_pca'.format(g)])
    ax.plot(globals()['{}_pca'.format(g)],label='{}_PCA'.format(g))

plt.legend()
plt.show()

# %% [markdown]
# 1. -2 SparsePCA - a variant of PCA with the goal of reduced data can reconstruct the original data

# %%
from sklearn.decomposition import SparsePCA
spca1 = SparsePCA(n_components=1)
spca2 = SparsePCA(n_components=2)
spca3 = SparsePCA(n_components=3)

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_spca'.format(g)] = spca3.fit_transform(globals()['{}_signal_filtered'.format(g)][40])
    globals()['{}_spca'.format(g)] = spca2.fit_transform(globals()['{}_spca'.format(g)])
    globals()['{}_spca'.format(g)] = spca1.fit_transform(globals()['{}_spca'.format(g)])
    ax.plot(globals()['{}_spca'.format(g)],label='{}_SPCA'.format(g))

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_spca'.format(g)] = spca3.fit_transform(globals()['{}_signal_filtered'.format(g)][80])
    globals()['{}_spca'.format(g)] = spca2.fit_transform(globals()['{}_spca'.format(g)])
    globals()['{}_spca'.format(g)] = spca1.fit_transform(globals()['{}_spca'.format(g)])
    ax.plot(globals()['{}_spca'.format(g)],label='{}_SPCA'.format(g))

plt.legend()
plt.show()

# %% [markdown]
# 2. Fast ICA - Independent Componete Analysis

# %%
from sklearn.decomposition import FastICA

fica1 = FastICA(n_components=1)
fica2 = FastICA(n_components=2)
fica3 = FastICA(n_components=3)

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_fica'.format(g)] = fica1.fit_transform(globals()['{}_signal_filtered'.format(g)][40])
    globals()['{}_fica'.format(g)] = fica2.fit_transform(globals()['{}_fica'.format(g)])
    globals()['{}_fica'.format(g)] = fica3.fit_transform(globals()['{}_fica'.format(g)])
    ax.plot(globals()['{}_fica'.format(g)],label='{}_FICA'.format(g))

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_fica'.format(g)] = fica1.fit_transform(globals()['{}_signal_filtered'.format(g)][40])
    globals()['{}_fica'.format(g)] = fica2.fit_transform(globals()['{}_fica'.format(g)])
    globals()['{}_fica'.format(g)] = fica3.fit_transform(globals()['{}_fica'.format(g)])
    ax.plot(globals()['{}_fica'.format(g)],label='{}_FICA'.format(g))

plt.legend()
plt.show()

# %% [markdown]
# 3. TSVD(Truncated Singular Value Decomposition) - performs linear dimensionality reduction by means of truncated SVD, contrary to PCA this does not center the data

# %%
from sklearn.decomposition import TruncatedSVD

tsvd1 = TruncatedSVD(n_components=1)
tsvd2 = TruncatedSVD(n_components=2)
tsvd3 = TruncatedSVD(n_components=3)

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_tsvd'.format(g)] = tsvd3.fit_transform(globals()['{}_signal_filtered'.format(g)][40])
    globals()['{}_tsvd'.format(g)] = tsvd2.fit_transform(globals()['{}_tsvd'.format(g)])
    globals()['{}_tsvd'.format(g)] = tsvd1.fit_transform(globals()['{}_tsvd'.format(g)])
    ax.plot(globals()['{}_tsvd'.format(g)],label='{}_TSVD'.format(g))

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_tsvd'.format(g)] = tsvd3.fit_transform(globals()['{}_signal_filtered'.format(g)][80])
    globals()['{}_tsvd'.format(g)] = tsvd2.fit_transform(globals()['{}_tsvd'.format(g)])
    globals()['{}_tsvd'.format(g)] = tsvd1.fit_transform(globals()['{}_tsvd'.format(g)])
    ax.plot(globals()['{}_tsvd'.format(g)],label='{}_TSVD'.format(g))

plt.legend()
plt.show()

# %% [markdown]
# 4. t-SNE(t-distributed Stochastic Neighbor Embedding) - calculate similarity between high dimensional data and low dimensional data and optimize (discrete)

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=1)

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_tsne'.format(g)] = tsne.fit_transform(globals()['{}_signal_filtered'.format(g)][40])
    ax.plot(globals()['{}_tsne'.format(g)],label='{}_TSNE'.format(g))

plt.legend()
plt.show()

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=1)

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_tsne'.format(g)] = tsne.fit_transform(globals()['{}_signal_filtered'.format(g)][80])
    ax.plot(globals()['{}_tsne'.format(g)],label='{}_TSNE'.format(g))

plt.legend()
plt.show()

# %% [markdown]
# 5. Isomap - non-linear Isometric Mapping

# %%
from sklearn.manifold import Isomap

isomap = Isomap(n_components=1)

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_isomap'.format(g)] = isomap.fit_transform(globals()['{}_signal_filtered'.format(g)][40])
    ax.plot(globals()['{}_isomap'.format(g)],label='{}_ISOMAP'.format(g))

plt.legend()
plt.show()

# %%
from sklearn.manifold import Isomap

isomap = Isomap(n_components=1)

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    globals()['{}_isomap'.format(g)] = isomap.fit_transform(globals()['{}_signal_filtered'.format(g)][80])
    ax.plot(globals()['{}_isomap'.format(g)],label='{}_ISOMAP'.format(g))

plt.legend()
plt.show()

# %% [markdown]
# Define functions

# %%
def Gesture_Max(sig):
    std_sig = standardscaler.fit_transform(sig)
    sig_max = np.max(std_sig[4000:5000,])

    for i in range(4):
        if np.any(np.isin(std_sig[4000:5000,i],sig_max)) == True: # know which channel has the maximum value when the gesture is engaged
            cut_ind = np.where(std_sig[4000:5000,i]==sig_max)[0][0] + 4000
            return cut_ind
    
def Cut_Box(sig, cut_ind, cut_size):
    cut_sig = sig[cut_ind-int(cut_size/2):cut_ind+int(cut_size/2)]
    return cut_sig

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    sig_filtered = globals()['{}_signal_filtered'.format(g)][40]
    globals()['{}_pca'.format(g)] = fica.fit_transform(minmaxscaler.fit_transform(standardscaler.fit_transform(sig_filtered)))
    sig_pca = globals()['{}_pca'.format(g)]
    cut_sig = Cut_Box(sig_pca, Gesture_Max(sig_filtered),500)

    ax.plot(cut_sig)

plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

for g in gesture_names[0:4]:
    sig_filtered = globals()['{}_signal_filtered'.format(g)][80]
    globals()['{}_pca'.format(g)] = fica.fit_transform(minmaxscaler.fit_transform(standardscaler.fit_transform(sig_filtered)))
    sig_pca = globals()['{}_pca'.format(g)]
    cut_sig = Cut_Box(sig_pca, Gesture_Max(sig_filtered),500)

    ax.plot(cut_sig)

plt.show()

# %% [markdown]
# Process all the data to fit model

# %%
for i in range(196): # 196(?) samples
    for g in gesture_names: # 10 gestures
        if i == 0:
            globals()['{}_processed'.format(g)] = np.zeros((globals()['{}_processed'.format(g)].shape[0],globals()['{}_processed'.format(g)].shape[1])) # make a 2-D array, columns are time and rows are classes
            globals()['{}_processed'.format(g)][i] = np.transpose(pca.fit_transform(minmaxscaler.fit_transform(globals()['{}_signal_filtered'.format(g)][i]))) # apply MinMaxScaler and PCA to the data
                
        else:
            globals()['{}_processed'.format(g)][i] = np.transpose(pca.fit_transform(minmaxscaler.fit_transform(globals()['{}_signal_filtered'.format(g)][i]))) # apply MinMaxScaler and PCA to the data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 4
#       2 for g in gesture_names: # 10 gestures
#       3     if i == 0:
# ----> 4         globals()['{}_processed'.format(g)] = np.zeros((globals()['{}_processed'.format(g)].shape[0],globals()['{}_processed'.format(g)].shape[1])) # make a 2-D array, columns are time and rows are classes
#       5         globals()['{}_processed'.format(g)][i] = np.transpose(pca.fit_transform(minmaxscaler.fit_transform(globals()['{}_signal_filtered'.format(g)][i]))) # apply MinMaxScaler and PCA to the data
#       7     else:
#
# KeyError: 'Rest_processed'

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.plot(Flexion_processed[90],label='90th')
ax.plot(Extension_processed[120],label='120th')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[246], line 3
#       1 fig = plt.figure(figsize=(20,10))
#       2 ax = fig.add_subplot(111)
# ----> 3 ax.plot(Flexion_processed[90],label='90th')
#       4 ax.plot(Extension_processed[120],label='120th')
#       6 plt.legend()
#
# NameError: name 'Flexion_processed' is not defined

# %% [markdown]
#  TSF(Time Series Forest) - Classification

# %%
from sktime.classification.all import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

X, y = Extension_processed, np.array(range(Extension_processed.shape[0]))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

classifier = TimeSeriesForestClassifier()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.0

# %%
classification_report(y_test, y_pred,output_dict=False)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.00      0.00      0.00       0.0\n           5       0.00      0.00      0.00       1.0\n           7       0.00      0.00      0.00       0.0\n           9       0.00      0.00      0.00       1.0\n          11       0.00      0.00      0.00       0.0\n          12       0.00      0.00      0.00       1.0\n          13       0.00      0.00      0.00       0.0\n          15       0.00      0.00      0.00       1.0\n          16       0.00      0.00      0.00       1.0\n          18       0.00      0.00      0.00       1.0\n          19       0.00      0.00      0.00       1.0\n          23       0.00      0.00      0.00       0.0\n          24       0.00      0.00      0.00       1.0\n          26       0.00      0.00      0.00       0.0\n          28       0.00      0.00      0.00       0.0\n          29       0.00      0.00      0.00       1.0\n          30       0.00      0.00      0.00       1.0\n          34       0.00      0.00      0.00       0.0\n          35       0.00      0.00      0.00       1.0\n          37       0.00      0.00      0.00       0.0\n          38       0.00      0.00      0.00       0.0\n          39       0.00      0.00      0.00       0.0\n          41       0.00      0.00      0.00       0.0\n          42       0.00      0.00      0.00       1.0\n          44       0.00      0.00      0.00       0.0\n          45       0.00      0.00      0.00       1.0\n          49       0.00      0.00      0.00       0.0\n          54       0.00      0.00      0.00       0.0\n          55       0.00      0.00      0.00       1.0\n          56       0.00      0.00      0.00       1.0\n          60       0.00      0.00      0.00       1.0\n          62       0.00      0.00      0.00       0.0\n          63       0.00      0.00      0.00       0.0\n          65       0.00      0.00      0.00       1.0\n          66       0.00      0.00      0.00       1.0\n          67       0.00      0.00      0.00       1.0\n          68       0.00      0.00      0.00       1.0\n          69       0.00      0.00      0.00       1.0\n          73       0.00      0.00      0.00       1.0\n          75       0.00      0.00      0.00       1.0\n          76       0.00      0.00      0.00       1.0\n          78       0.00      0.00      0.00       1.0\n          80       0.00      0.00      0.00       0.0\n          81       0.00      0.00      0.00       0.0\n          82       0.00      0.00      0.00       1.0\n          85       0.00      0.00      0.00       1.0\n          88       0.00      0.00      0.00       0.0\n          91       0.00      0.00      0.00       0.0\n          93       0.00      0.00      0.00       1.0\n          95       0.00      0.00      0.00       1.0\n          96       0.00      0.00      0.00       0.0\n          97       0.00      0.00      0.00       1.0\n         100       0.00      0.00      0.00       0.0\n         101       0.00      0.00      0.00       0.0\n         103       0.00      0.00      0.00       0.0\n         104       0.00      0.00      0.00       0.0\n         111       0.00      0.00      0.00       0.0\n         112       0.00      0.00      0.00       1.0\n         113       0.00      0.00      0.00       1.0\n         114       0.00      0.00      0.00       1.0\n         115       0.00      0.00      0.00       1.0\n         118       0.00      0.00      0.00       1.0\n         119       0.00      0.00      0.00       1.0\n         121       0.00      0.00      0.00       0.0\n         122       0.00      0.00      0.00       1.0\n         123       0.00      0.00      0.00       1.0\n         124       0.00      0.00      0.00       1.0\n         126       0.00      0.00      0.00       0.0\n         127       0.00      0.00      0.00       0.0\n         128       0.00      0.00      0.00       1.0\n         130       0.00      0.00      0.00       0.0\n         132       0.00      0.00     ...

# %% [markdown]
#     SAD

# %%
"""
for i in range(40): #data1 to data40
    globals()['data{}'.format(i+1)] = pd.read_csv('/Users/jhr/workspace/GitHub/EMG_data_analysis/Dataset for multi-channel surface electromyography (sEMG) signals of hand gestures/sEMG-dataset/raw/csv/{}_raw.csv'.format(i+1), names=col_names)

    globals()['data{}_pattern'.format(i+1)] = [globals()['data{}'.format(i+1)][r:r + 268000] for r in range(0, len(globals()['data{}'.format(i+1)]), 268000)] #divide the data by 268000 steps at a time

    for f in col_names: #ch1 to ch4
        
        for j in range(5): #pattern1 to pattern5
            
            for g in range(10): #gesture1 to gesture10
                if g == 0: #make a dataframe what sets the standard index
                    globals()['data{}_gestures{}'.format(i+1,j+1)] = np.array_split(globals()['data{}_pattern'.format(i+1)][j].iloc[4000:204000], 10) #split the data into 10 gestures
                    globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)] = pd.DataFrame(globals()['data{}_gestures{}'.format(i+1,j+1)][g][f]) #new dataframe to set columns as gestures

                else: #appending the other features by pd.concat
                    globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)] = pd.concat([globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)],pd.DataFrame(globals()['data{}_gestures{}'.format(i+1,j+1)][g][f]).set_index(globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)].index)],axis=1,join='inner')
                    globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)].reset_index(drop=True, inplace=True) #reset the index

                    globals()['data{}_{}_gestures{}_litre'.format(i+1,f,j+1)] = globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)].iloc[3000:17000] #new dataframe with a little of the rest time(0:4000, 16000:20000)
                    globals()['data{}_{}_gestures{}_litre'.format(i+1,f,j+1)].reset_index(drop=True, inplace=True) #reset the index
            
            globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)].columns = gesture_names #rename the columns by the exact gesture names
            globals()['data{}_{}_gestures{}_litre'.format(i+1,f,j+1)].columns = gesture_names #rename the columns by the exact gesture names
"""
# Out:
# "\nfor i in range(40): #data1 to data40\n    globals()['data{}'.format(i+1)] = pd.read_csv('/Users/jhr/workspace/GitHub/EMG_data_analysis/Dataset for multi-channel surface electromyography (sEMG) signals of hand gestures/sEMG-dataset/raw/csv/{}_raw.csv'.format(i+1), names=col_names)\n\n    globals()['data{}_pattern'.format(i+1)] = [globals()['data{}'.format(i+1)][r:r + 268000] for r in range(0, len(globals()['data{}'.format(i+1)]), 268000)] #divide the data by 268000 steps at a time\n\n    for f in col_names: #ch1 to ch4\n        \n        for j in range(5): #pattern1 to pattern5\n            \n            for g in range(10): #gesture1 to gesture10\n                if g == 0: #make a dataframe what sets the standard index\n                    globals()['data{}_gestures{}'.format(i+1,j+1)] = np.array_split(globals()['data{}_pattern'.format(i+1)][j].iloc[4000:204000], 10) #split the data into 10 gestures\n                    globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)] = pd.DataFrame(globals()['data{}_gestures{}'.format(i+1,j+1)][g][f]) #new dataframe to set columns as gestures\n\n                else: #appending the other features by pd.concat\n                    globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)] = pd.concat([globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)],pd.DataFrame(globals()['data{}_gestures{}'.format(i+1,j+1)][g][f]).set_index(globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)].index)],axis=1,join='inner')\n                    globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)].reset_index(drop=True, inplace=True) #reset the index\n\n                    globals()['data{}_{}_gestures{}_litre'.format(i+1,f,j+1)] = globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)].iloc[3000:17000] #new dataframe with a little of the rest time(0:4000, 16000:20000)\n                    globals()['data{}_{}_gestures{}_litre'.format(i+1,f,j+1)].reset_index(drop=True, inplace=True) #reset the index\n            \n            globals()['data{}_{}_gestures{}'.format(i+1,f,j+1)].columns = gesture_names #rename the columns by the exact gesture names\n            globals()['data{}_{}_gestures{}_litre'.format(i+1,f,j+1)].columns = gesture_names #rename the columns by the exact gesture names\n"

# %%
"""
#Remove 'Ulnar Deviation', 'Radial Deviation', 'Abduction of Fingers', 'Adduction of Fingers' (no remarkable signal characteristic between two similar)
for i in range(40):
    for j in range(4):
        for k in range(5):
            globals()['data{}_ch{}_gestures{}_litre'.format(i+1,j+1,k+1)].drop(columns=['Ulnar Deviation', 'Radial Deviation', 'Abduction of Fingers', 'Adduction of Fingers'], inplace=True)
"""
# Out:
# "\nfor i in range(40):\n    for j in range(4):\n        for k in range(5):\n            globals()['data{}_ch{}_gestures{}_litre'.format(i+1,j+1,k+1)].drop(columns=['Ulnar Deviation', 'Radial Deviation', 'Abduction of Fingers', 'Adduction of Fingers'], inplace=True)\n"
